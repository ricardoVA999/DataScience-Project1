# %% [markdown]
# # Proyecto 1 Limpieza de datos de las instituciones educativas de Guatemala

# %% [markdown]
# ### Ricardo Valenzuela 18762
# ### Amado Garcia 181469
# ### Sara Zavala 18893

# %% [markdown]
# ## Cargar todos los datasets

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np

# %%
AltVer = pd.read_csv("BaseDeDatos/csv/AltaVerapaz.csv", encoding='latin1')
BajVer = pd.read_csv("BaseDeDatos/csv/BajaVerapaz.csv", encoding='latin1')
Chimal = pd.read_csv("BaseDeDatos/csv/Chimaltenango.csv", encoding='latin1')
Chiqui = pd.read_csv("BaseDeDatos/csv/Chiquimula.csv", encoding='latin1')
CiuCap = pd.read_csv("BaseDeDatos/csv/CiudadCapital.csv", encoding='latin1')
Prog = pd.read_csv("BaseDeDatos/csv/ElProgreso.csv", encoding='latin1')
Escui = pd.read_csv("BaseDeDatos/csv/Escuintla.csv", encoding='latin1')
Guate = pd.read_csv("BaseDeDatos/csv/Guatemala.csv", encoding='latin1')
Huehue = pd.read_csv("BaseDeDatos/csv/Huehuetenango.csv", encoding='latin1')
Izab = pd.read_csv("BaseDeDatos/csv/Izabal.csv", encoding='latin1')

# %%
Jala = pd.read_csv("BaseDeDatos/csv/Jalapa.csv", encoding='latin1')
Juti = pd.read_csv("BaseDeDatos/csv/Jutiapa.csv", encoding='latin1')
Peten = pd.read_csv("BaseDeDatos/csv/Peten.csv", encoding='latin1')
Quetza = pd.read_csv("BaseDeDatos/csv/Quetzaltenango.csv", encoding='latin1')
Quiche = pd.read_csv("BaseDeDatos/csv/Quiche.csv", encoding='latin1')
Retal = pd.read_csv("BaseDeDatos/csv/Retalhuleu.csv", encoding='latin1')
Sacat = pd.read_csv("BaseDeDatos/csv/Sacatepequez.csv", encoding='latin1')
SanMa = pd.read_csv("BaseDeDatos/csv/SanMarcos.csv", encoding='latin1')
SantRo = pd.read_csv("BaseDeDatos/csv/SantaRosa.csv", encoding='latin1')
Solola = pd.read_csv("BaseDeDatos/csv/Solola.csv", encoding='latin1')

# %%
Suchi = pd.read_csv("BaseDeDatos/csv/Suchitepequez.csv", encoding='latin1')
Toton = pd.read_csv("BaseDeDatos/csv/Totonicapan.csv", encoding='latin1')
Zacap = pd.read_csv("BaseDeDatos/csv/Zacapa.csv", encoding='latin1')

# %%
Guate.columns = ['CODIGO',
 'DISTRITO',
 'DEPARTAMENTO',
 'MUNICIPIO',
 'ESTABLECIMIENTO',
 'DIRECCION',
 'TELEFONO',
 'SUPERVISOR',
 'DIRECTOR',
 'NIVEL',
 'SECTOR',
 'AREA',
 'STATUS',
 'MODALIDAD',
 'JORNADA',
 'PLAN',
 'DEPARTAMENTAL']

# %% [markdown]
# ## Union de Datasets

# %%
departamentos = [AltVer, BajVer, Chimal, Chiqui, CiuCap, Prog, Escui, Guate, Huehue, Izab,
                 Jala, Juti, Peten, Quetza, Quiche, Retal, Sacat, SanMa, SantRo, Solola, 
                 Suchi, Toton, Zacap]
col_guate = pd.concat(departamentos)

# %%
col_guate
# Out:
#            CODIGO DISTRITO  DEPARTAMENTO  MUNICIPIO  \
# 0   16-01-0138-46   16-031  ALTA VERAPAZ      COBAN
# 1   16-01-0139-46   16-031  ALTA VERAPAZ      COBAN
# 2   16-01-0140-46   16-031  ALTA VERAPAZ      COBAN
# 3   16-01-0141-46   16-005  ALTA VERAPAZ      COBAN
# 4   16-01-0142-46   16-005  ALTA VERAPAZ      COBAN
# ..            ...      ...           ...        ...
# 88  19-09-0040-46   19-026        ZACAPA   LA UNION
# 89  19-09-0902-46   19-026        ZACAPA   LA UNION
# 90  19-10-0013-46   19-016        ZACAPA      HUITE
# 91  19-10-1009-46   19-016        ZACAPA      HUITE
# 92  19-11-0018-46   19-020        ZACAPA  SAN JORGE
#
#                                       ESTABLECIMIENTO  \
# 0                                       COLEGIO COBAN
# 1                    COLEGIO PARTICULAR MIXTO VERAPAZ
# 2                               COLEGIO LA INMACULADA
# 3            ESCUELA NACIONAL DE CIENCIAS COMERCIALES
# 4   INSTITUTO NORMAL MIXTO DEL NORTE 'EMILIO ROSAL...
# ...

# %%
df = pd.value_counts(col_guate.TELEFONO).to_frame().reset_index()
df.columns = ['Col_value','Count']
df
# Out:
#               Col_value  Count
# 0              78394519     12
# 1              79480009     11
# 2              22322912     10
# 3              77282600     10
# 4              22093200      9
# ...                 ...    ...
# 3157           24361224      1
# 3158           24345193      1
# 3159  24345193 24361224      1
# 3160           24351948      1
# 3161         41447589.0      1
#
# [3162 rows x 2 columns]

# %%
col_guate.index = list(range(0,8099))

# %% [markdown]
# ## Revision de datos

# %%
profile = ProfileReport(col_guate)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-07-26 21:28:41.223829&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df = pd.value_counts(col_guate.DIRECCION).to_frame().reset_index()
df.columns = ['Value','Count']
for element in df.Value:
    print(element)
# Out:
# CABECERA MUNICIPAL
# BARRIO EL CENTRO
# BARRIO EL PORVENIR
# ZONA 1 PLAYA GRANDE
# BARRIO EL CALVARIO
# 1A. CALLE 9-307 ZONA 4
# 3A. CALLE 6-125 ZONA 4
# 12 CALLE 10-37
# 6A. AVENIDA 3-48 ZONA 5
# BARRIO GUAYTAN
# COLONIA MORÁN
# 15 CALLE 3-29
# 3A. AVENIDA 1-64 ZONA 2
# 2A. CALLE 4-43 ZONA 3
# CANTÓN SAN SEBASTIÁN
# 1A. AVENIDA 4-52 ZONA 4
# CALZADA SAN JUAN 31-47
# 6AV. 2-17 ZONA 4
# 1A. CALLE 2-39 ZONA 4
# 2A. CALLE 4-70 ZONA 4
# 2A. CALLE 1-34 ZONA 1
# BARRIO LAS FLORES
# PRIMER CANTÓN
# .
# BARRIO EL CARRIZAL
# CALLE PRINCIPAL
# ALDEA LAS POZAS
# BARRIO 3 DE ABRIL
# BARRIO LA LIBERTAD
# ALDEA FRONTERAS RIO DULCE
# CANTON SAN LORENZO
# ALDEA CAMOJALLITO
# 11 CALLE 3-59
# 2A. CALLE 2-44 ZONA 1
# 3ERA. CALLE 7-54 ZONA 3
# ALDEA EL NARANJO
# 4A. AVENIDA 5-80 ZONA 2
# CALLE CHIPILAPA NO. 11
# BARRIO CENTRAL
# 7A CALLE 3-40 ZONA 1
# BARRIO BUENOS AIRES
# 2A. CALLE 12-23 ZONA 4
# BARRIO SAN SEBASTIAN
# 1A. CALLE 1-63 ZONA 5
# 2A. CALLE 2-35 ZONA 2
# 12 CALLE 4-57 ZONA 1
# ...
